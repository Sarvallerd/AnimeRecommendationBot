# %%
import pandas as pd
import numpy as np
from gensim import models
import re
from sklearn.metrics.pairwise import cosine_similarity, euclidean_distances
from sklearn.cluster import KMeans, DBSCAN
from sklearn.preprocessing import LabelEncoder, StandardScaler
import matplotlib.pyplot as plt

DATA_PATH = "../../data/"
MODELS_PATH = "../../models/"

# %%
anime_df = pd.read_csv(DATA_PATH + 'anime_full.csv')
anime_df.head()
# Out:
#    MAL_ID                    Name  Score   Type  Episodes    Source  Duration  \
# 0     1.0            Cowboy Bebop   8.78     TV      26.0  Original      1440
# 1     5.0  Cowboy Bebop:The Movie   8.39  Movie       1.0  Original      6900
# 2     6.0                  Trigun   8.24     TV      26.0     Manga      1440
# 3     7.0      Witch Hunter Robin   7.27     TV      26.0  Original      1500
# 4     8.0  Beet the Vandel Buster   6.98     TV      52.0     Manga      1380
#
#    Rating  Popularity  Favorites  ... Super Power  Shoujo Ai  Kids  Police  \
# 0      18        39.0    61971.0  ...           0          0     0       0
# 1      18       518.0     1174.0  ...           0          0     0       0
# 2      13       201.0    12944.0  ...           0          0     0       0
# 3      13      1467.0      587.0  ...           0          0     0       1
# 4       7      4369.0       18.0  ...           0          0     0       0
#
#    Slice of Life  Yaoi  Josei  Cars  season  year
# 0              0     0      0     0  spring  1998
# 1              0     0      0     0  autumn  2001
# 2              0     0      0     0  spring  1998
# 3              0     0      0     0  summer  2002
# 4              0     0      0     0  autumn  2004
#
# [5 rows x 54 columns]

# %%
anime_df.shape
# Out:
# (10882, 54)

# %% [markdown]
# ## Create full discription and clusterning

# %%
def create_full_discription(df):
    df = df.copy()
    unique_genres = df.loc[0]['Action': 'Cars'].index.values
    df = df.drop(columns=unique_genres)
    genres = pd.read_csv(DATA_PATH + 'anime.csv')[['MAL_ID', 'Genres']]
    df = pd.merge(df, genres, on='MAL_ID', how='left')
    df = df.drop(columns='MAL_ID')
    full_sypn = df.apply(lambda x: re.sub(r'[^\w\s]', '', str(x.to_dict()).lower()), axis=1).to_list()
    return full_sypn

# %%
def get_clusters(df):
    df = df.copy()
    unique_genres = df.loc[0]['Action': 'Cars'].index.values
    km = KMeans(n_clusters=20, random_state=22)
    km.fit(df[unique_genres])
    df['cluster'] = km.labels_
    return df

# %%
anime_df = get_clusters(anime_df)
# Out:
# C:\Users\kloko\.conda\envs\AnimeRecommendation\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
anime_df.head()
# Out:
#    MAL_ID                    Name  Score   Type  Episodes    Source  Duration  \
# 0     1.0            Cowboy Bebop   8.78     TV      26.0  Original      1440
# 1     5.0  Cowboy Bebop:The Movie   8.39  Movie       1.0  Original      6900
# 2     6.0                  Trigun   8.24     TV      26.0     Manga      1440
# 3     7.0      Witch Hunter Robin   7.27     TV      26.0  Original      1500
# 4     8.0  Beet the Vandel Buster   6.98     TV      52.0     Manga      1380
#
#    Rating  Popularity  Favorites  ... Shoujo Ai  Kids  Police  Slice of Life  \
# 0      18        39.0    61971.0  ...         0     0       0              0
# 1      18       518.0     1174.0  ...         0     0       0              0
# 2      13       201.0    12944.0  ...         0     0       0              0
# 3      13      1467.0      587.0  ...         0     0       1              0
# 4       7      4369.0       18.0  ...         0     0       0              0
#
#    Yaoi  Josei  Cars  season  year  cluster
# 0     0      0     0  spring  1998        3
# 1     0      0     0  autumn  2001        3
# 2     0      0     0  spring  1998        5
# 3     0      0     0  summer  2002       14
# 4     0      0     0  autumn  2004       16
#
# [5 rows x 55 columns]

# %%
anime_df.drop(columns='MAL_ID').to_csv(DATA_PATH + 'anime_cl.csv', index=False)

# %% [markdown]
# ### Create embeddings

# %%
glove_df = pd.read_csv(MODELS_PATH + 'glove.6B.300d.txt', sep=" ",
                       quoting=3, header=None, index_col=0)
glove_model = {key: value.values for key, value in glove_df.T.items()}

# %%
full_sypn = create_full_discription(anime_df)

# %%
def glove(sypn_list):
    vector_matrix = np.empty((len(sypn_list), 300))
    
    for index, each_sentence in enumerate(sypn_list):
        sentence_vector = np.zeros((300,))
        for each_word in each_sentence.split():
            try:
                sentence_vector += glove_model[each_word]
                
            except:
                continue
        vector_matrix[index] = sentence_vector
        
    np.savez(DATA_PATH + 'matrix', vector_matrix)

# %%
glove(full_sypn)
